# %%
# Step One - Choose Your Data Set

# %%
import numpy as np
import pandas as pd

titanic_df = pd.read_csv('titanic_data.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# Step Two - Get Organized

# %%
print titanic_df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
print titanic_df.mean().describe()
# Out:
# count      7.000000
# mean      73.071487
# std      165.058045
# min        0.381594
# 25%        0.453423
# 50%        2.308642
# 75%       30.951663
# max      446.000000
# dtype: float64

# %%
titanic_df['Survived'].count()
# Out:
# 891

# %%
titanic_df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
titanic_df['Pclass'].describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
data_by_class = titanic_df.groupby(['Sex', 'Fare'],
                                    as_index=False).mean()
data_by_class
# Out:
#         Sex      Fare  PassengerId  Survived  Pclass        Age     SibSp  \
# 0    female    6.7500   655.000000  0.000000     3.0  18.000000  0.000000
# 1    female    7.2250   448.000000  1.000000     3.0  15.000000  0.000000
# 2    female    7.2292   574.500000  1.000000     3.0  13.000000  0.000000
# 3    female    7.2500   377.000000  1.000000     3.0  22.000000  0.000000
# 4    female    7.4958   787.000000  1.000000     3.0  18.000000  0.000000
# 5    female    7.5500   443.000000  0.500000     3.0  23.000000  0.000000
# 6    female    7.6292   503.000000  0.000000     3.0        NaN  0.000000
# 7    female    7.6500   107.000000  1.000000     3.0  21.000000  0.000000
# 8    female    7.7333   427.500000  1.000000     3.0  16.000000  0.000000
# 9    female    7.7375   728.000000  1.000000     3.0        NaN  0.000000
# 10   female    7.7500   323.066667  0.666667     3.0  26.083333  0.000000
# 11   female    7.7750   536.666667  0.333333     3.0  21.666667  0.000000
# ...

# %%
# %pylab inline
import matplotlib.pyplot as plt
import seaborn as sns


scaled_class = (data_by_class['Age'] / 
                 data_by_class['Age'].mean())

plt.scatter(data_by_class['Sex'], data_by_class['Fare'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_by_class.plot()
